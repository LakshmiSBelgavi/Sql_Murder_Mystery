# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshmiSBelgavi/Sql_Murder_Mystery/blob/main/murder_mystery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql

# %%
con = sql.connect('/content/sql-murder-mystery.db')

# %%
print(con)

# %% [markdown]
# **1.  Retrieve Crime Scene Report:**
#
# Task: Run a query to retrieve the crime scene report for the murder that occurred on Jan.15, 2018, in SQL City. Gather all available details from the report.

# %%
query1 = """
SELECT * FROM crime_scene_report WHERE type = 'murder' AND city = 'SQL City' AND date = 20180115
 """

# %%
crime_scene_report = pd.read_sql_query(query1,con)

# %%
crime_scene_report
# Out:
#        date    type                                        description  \
# 0  20180115  murder  Security footage shows that there were 2 witne...
#
#        city
# 0  SQL City

# %% [markdown]
# **2. Witness Personal Details:**
#
# Task: Check the personal details of witnesses involved in the case. Retrieve their names, addresses, and any other relevant information.

# %%
wit1 = """
SELECT * FROM person WHERE address_street_name='Northwestern Dr' order by address_number
DESC LIMIT 1
"""

# %%
info =  pd.read_sql_query(wit1,con)

# %%
info
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %%
wit2="""
SELECT * FROM person
WHERE address_street_name = 'Franklin Ave'
AND name LIKE '%Annabel%'
"""

# %%
info1 = pd.read_sql_query(wit2,con)

# %%
info1
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# **3. View Witness Interviews:**
#
# Task: Access the recorded interviews of witnesses conducted after the murder. Gather insights into their statements and potential clues.

# %%
query3 = """
SELECT * FROM interview WHERE person_id IN (14887,16371)
"""

# %%
interview = pd.read_sql_query(query3,con)

# %%
interview
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...
# 1      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# **4. Check Gym Database:**
#
# Task: Investigate the gym database using details obtained from the crime scene report and witness interviews. Look for any gym-related information that might be relevant.

# %%
query4 = """
SELECT * FROM get_fit_now_member WHERE id='48Z55'
"""

# %%
gym_db = pd.read_sql_query(query4,con)

# %%
gym_db
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# **5. Check Car Details:**
#
# Task: Examine the car details associated with the crime scene. Retrieve information about the vehicles present during the incident.

# %%
query4 = """
SELECT * FROM drivers_license WHERE plate_number = '0H42W2'
"""

# %%
car_details = pd.read_sql_query(query4,con)

# %%
print(car_details)
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#   car_model
# 0  Spark LS

# %% [markdown]
# **6. Personal Details:**
#
# Task: Identify and collect personal details mentioned in the previous query. This includes names, addresses, and any additional details.

# %%
query6 = """
SELECT * FROM person WHERE license_id = '423327'
"""

# %%
personal_details = pd.read_sql_query(query6,con)

# %%
personal_details
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  871539279

# %% [markdown]
# **7. Membership Status at the Gym:**
#
# Task: Determine who is identified in the previous query as a member of the gym. Utilize the gym database to confirm their membership status.

# %%
query7 = """
 SELECT p.name, p.id AS person_id, gfn.membership_status FROM person AS p
 INNER JOIN get_fit_now_member AS gfn ON p.id = gfn.person_id WHERE p.license_id = '423327'
 """

# %%
gym_status = pd.read_sql_query(query7,con)

# %%
gym_status
# Out:
#             name  person_id membership_status
# 0  Jeremy Bowers      67318              gold

# %%
query = """
SELECT * FROM interview WHERE person_id=67318
"""

# %%
result = pd.read_sql_query(query,con)

# %%
result
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %%
#We got the third suspect

wit3 = """
SELECT * FROM drivers_license where gender='female' AND car_make LIKE 'Tesla%' AND car_model ='Model S' AND hair_color='red'
"""

# %%
info = pd.read_sql_query(wit3,con)

# %%
info
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %%
details = """
SELECT * FROM facebook_event_checkin WHERE event_name='SQL Symphony Concert' AND person_id IN (78881,90700,99716)
"""

# %%
info = pd.read_sql_query(details,con)

# %%
info
# Out:
#    person_id  event_id            event_name      date
# 0      99716      1143  SQL Symphony Concert  20171206
# 1      99716      1143  SQL Symphony Concert  20171212
# 2      99716      1143  SQL Symphony Concert  20171229

# %% [markdown]
# From the above table we can say that only one person attended this concert and 3 times hence person_id 99716 is
# suspect whose name is ***Miranda Priestly.***
